# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Read the dataset file
data = pd.read_csv('/kaggle/input/iriscsv/Iris.csv', index_col = 0)

# %%
#Display the first five rows of the dataframe
print(data.head())
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Displaying the information of the dataframe
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB
# None

# %%
print(data.shape)
# Out:
# (150, 5)

# %%
# check there is no null values and check for missing values
print(data.isna().sum())
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#Check for duplicates
print(data.duplicated(keep = False).value_counts())
print(data[data.duplicated(keep = False)])
# Out:
# False    145
# True       5
# Name: count, dtype: int64
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 10             4.9           3.1            1.5           0.1     Iris-setosa
# 35             4.9           3.1            1.5           0.1     Iris-setosa
# 38             4.9           3.1            1.5           0.1     Iris-setosa
# 102            5.8           2.7            5.1           1.9  Iris-virginica
# 143            5.8           2.7            5.1           1.9  Iris-virginica

# %%
#Drop duplicates
data = data.drop_duplicates(keep = 'first').copy()
print(data.shape)
# Out:
# (147, 5)

# %%
#Reset the index of the dataframe

data = data.reset_index(drop = True)

# %%
#Split the dataframe into X(features) and y(target or labels)
X = data.iloc[:, 0:4].values
y = data['Species'].values

# %%
print(X.shape)
print(y.shape)
# Out:
# (147, 4)
# (147,)

# %%
#Normalization on X
scaler = MinMaxScaler()
scaler.fit(X)
X_scaled = scaler.fit_transform(X)

# %%
#Convert target using LabelEncoder
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)

# %%
#Categorically encoding the labels

num_categories = 3
y_onehot = keras.utils.to_categorical(y_encoded, num_categories)

# %%
#convert X_scaled and y_onehot into train and valid data

X_train, X_valid, y_train, y_valid = train_test_split(X_scaled, y_onehot,
                                                     test_size = 0.2,
                                                     random_state = 42)

# %%
#Define a model

model = Sequential()
model.add(Dense(units = 512, activation = 'relu', input_shape = (4,)))
model.add(Dense(units = 512, activation = 'relu'))
model.add(Dense(units = 512, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = num_categories, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               2560
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_3 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 529,411
# Trainable params: 529,411
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compiling the model

model.compile(loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history=model.fit(X_train, y_train,
          epochs = 100,
          verbose = 1,
          validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 6s 74ms/step - loss: 0.9927 - accuracy: 0.4872 - val_loss: 0.7780 - val_accuracy: 0.6667
# Epoch 2/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7071 - accuracy: 0.6838 - val_loss: 0.5791 - val_accuracy: 0.6667
# Epoch 3/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5131 - accuracy: 0.7094 - val_loss: 0.4566 - val_accuracy: 0.7333
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5268 - accuracy: 0.6325 - val_loss: 0.4320 - val_accuracy: 0.7333
# Epoch 5/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4383 - accuracy: 0.7436 - val_loss: 0.4514 - val_accuracy: 0.6667
# Epoch 6/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3871 - accuracy: 0.8291 - val_loss: 0.4435 - val_accuracy: 0.6667
# Epoch 7/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3699 - accuracy: 0.7692 - val_loss: 0.3821 - val_accuracy: 0.7333
# Epoch 8/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3505 - accuracy: 0.8462 - val_loss: 0.3148 - val_accuracy: 0.9000
# Epoch 9/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4737 - accuracy: 0.7778 - val_loss: 0.3328 - val_accuracy: 0.8667
# Epoch 10/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3397 - accuracy: 0.8376 - val_loss: 0.2989 - val_accuracy: 0.9000
# Epoch 11/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2685 - accuracy: 0.9316 - val_loss: 0.2898 - val_accuracy: 0.9000
# Epoch 12/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3713 - accuracy: 0.7778 - val_loss: 0.2757 - val_accuracy: 0.9000
# Epoch 13/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2624 - accuracy: 0.8974 - val_loss: 0.2728 - val_accuracy: 0.9000
# Epoch 14/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2130 - accuracy: 0.9231 - val_loss: 0.3162 - val_accuracy: 0.8667
# Epoch 15/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2096 - accuracy: 0.9145 - val_loss: 0.2884 - val_accuracy: 0.8333
# Epoch 16/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3534 - accuracy: 0.8034 - val_loss: 0.2647 - val_accuracy: 0.8667
# Epoch 17/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2275 - accuracy: 0.9231 - val_loss: 0.2166 - val_accuracy: 0.9000
# Epoch 18/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2197 - accuracy: 0.9060 - val_loss: 0.2396 - val_accuracy: 0.8667
# Epoch 19/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1995 - accuracy: 0.9402 - val_loss: 0.2258 - val_accuracy: 0.9000
# Epoch 20/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1867 - accuracy: 0.9231 - val_loss: 0.2810 - val_accuracy: 0.8333
# Epoch 21/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2627 - accuracy: 0.8803 - val_loss: 0.1996 - val_accuracy: 0.9333
# Epoch 22/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1256 - accuracy: 0.9658 - val_loss: 0.2176 - val_accuracy: 0.9000
# Epoch 23/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1182 - accuracy: 0.9487 - val_loss: 0.1835 - val_accuracy: 0.9333
# Epoch 24/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1909 - accuracy: 0.9231 - val_loss: 0.1684 - val_accuracy: 0.9000
# Epoch 25/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2301 - accuracy: 0.8974 - val_loss: 0.1667 - val_accuracy: 0.9333
# Epoch 26/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1056 - accuracy: 0.9744 - val_loss: 0.1598 - val_accuracy: 0.9333
# Epoch 27/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0852 - accuracy: 0.9658 - val_loss: 0.2558 - val_accuracy: 0.9000
# Epoch 28/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1892 - accuracy: 0.9060 - val_loss: 0.5326 - val_accuracy: 0.8000
# Epoch 29/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1505 - accuracy: 0.9316 - val_loss: 0.2135 - val_accuracy: 0.9333
# Epoch 30/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0940 - accuracy: 0.9487 - val_loss: 0.1480 - val_accuracy: 0.9333
# Epoch 31/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1619 - accuracy: 0.9316 - val_loss: 0.3354 - val_accuracy: 0.8667
# Epoch 32/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3077 - accuracy: 0.8889 - val_loss: 0.1680 - val_accuracy: 0.9333
# Epoch 33/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0700 - accuracy: 0.9573 - val_loss: 0.2267 - val_accuracy: 0.9333
# Epoch 34/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0852 - accuracy: 0.9487 - val_loss: 0.2264 - val_accuracy: 0.9333
# Epoch 35/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0668 - accuracy: 0.9744 - val_loss: 0.2122 - val_accuracy: 0.9333
# Epoch 36/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0612 - accuracy: 0.9744 - val_loss: 0.1660 - val_accuracy: 0.9000
# Epoch 37/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0799 - accuracy: 0.9744 - val_loss: 0.1596 - val_accuracy: 0.9333
# Epoch 38/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0557 - accuracy: 0.9744 - val_loss: 0.1247 - val_accuracy: 0.9333
# Epoch 39/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2012 - accuracy: 0.9316 - val_loss: 0.3031 - val_accuracy: 0.8667
# Epoch 40/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1142 - accuracy: 0.9573 - val_loss: 0.2476 - val_accuracy: 0.9333
# Epoch 41/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0757 - accuracy: 0.9658 - val_loss: 0.1913 - val_accuracy: 0.9333
# Epoch 42/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0618 - accuracy: 0.9744 - val_loss: 0.1712 - val_accuracy: 0.9333
# Epoch 43/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0997 - accuracy: 0.9573 - val_loss: 0.2558 - val_accuracy: 0.9333
# Epoch 44/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0560 - accuracy: 0.9744 - val_loss: 0.2031 - val_accuracy: 0.9333
# Epoch 45/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0489 - accuracy: 0.9915 - val_loss: 0.2003 - val_accuracy: 0.9333
# Epoch 46/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0652 - accuracy: 0.9829 - val_loss: 0.1843 - val_accuracy: 0.9333
# Epoch 47/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2479 - accuracy: 0.8889 - val_loss: 0.1344 - val_accuracy: 0.9333
# Epoch 48/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0518 - accuracy: 0.9744 - val_loss: 0.1008 - val_accuracy: 0.9333
# Epoch 49/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0560 - accuracy: 0.9658 - val_loss: 0.1039 - val_accuracy: 0.9667
# Epoch 50/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0514 - accuracy: 0.9744 - val_loss: 0.1784 - val_accuracy: 0.9333
# Epoch 51/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1036 - accuracy: 0.9402 - val_loss: 0.2569 - val_accuracy: 0.9333
# Epoch 52/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0644 - accuracy: 0.9744 - val_loss: 0.1884 - val_accuracy: 0.9000
# Epoch 53/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1798 - accuracy: 0.9145 - val_loss: 0.6259 - val_accuracy: 0.8000
# Epoch 54/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2501 - accuracy: 0.9145 - val_loss: 0.1523 - val_accuracy: 0.9333
# Epoch 55/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0880 - accuracy: 0.9658 - val_loss: 0.3512 - val_accuracy: 0.8667
# Epoch 56/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0891 - accuracy: 0.9573 - val_loss: 0.1200 - val_accuracy: 0.9333
# Epoch 57/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0664 - accuracy: 0.9658 - val_loss: 0.1090 - val_accuracy: 0.9667
# Epoch 58/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0510 - accuracy: 0.9915 - val_loss: 0.1607 - val_accuracy: 0.9333
# Epoch 59/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0792 - accuracy: 0.9658 - val_loss: 0.2485 - val_accuracy: 0.9333
# Epoch 60/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0514 - accuracy: 0.9829 - val_loss: 0.1891 - val_accuracy: 0.9333
# Epoch 61/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0526 - accuracy: 0.9829 - val_loss: 0.1549 - val_accuracy: 0.9333
# Epoch 62/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0501 - accuracy: 0.9744 - val_loss: 0.3169 - val_accuracy: 0.9333
# Epoch 63/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0689 - accuracy: 0.9829 - val_loss: 0.4937 - val_accuracy: 0.8000
# Epoch 64/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1771 - accuracy: 0.9402 - val_loss: 0.1777 - val_accuracy: 0.9333
# Epoch 65/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0589 - accuracy: 0.9744 - val_loss: 0.1132 - val_accuracy: 0.9333
# Epoch 66/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0832 - accuracy: 0.9658 - val_loss: 0.1049 - val_accuracy: 0.9333
# Epoch 67/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0575 - accuracy: 0.9829 - val_loss: 0.2442 - val_accuracy: 0.9333
# Epoch 68/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1118 - accuracy: 0.9487 - val_loss: 0.0905 - val_accuracy: 0.9667
# Epoch 69/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.2251 - val_accuracy: 0.9333
# Epoch 70/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0441 - accuracy: 0.9829 - val_loss: 0.2173 - val_accuracy: 0.9333
# Epoch 71/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0419 - accuracy: 0.9829 - val_loss: 0.2748 - val_accuracy: 0.9333
# Epoch 72/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1732 - accuracy: 0.9402 - val_loss: 0.5087 - val_accuracy: 0.8000
# Epoch 73/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1136 - accuracy: 0.9402 - val_loss: 0.1489 - val_accuracy: 0.9333
# Epoch 74/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0367 - accuracy: 0.9829 - val_loss: 0.1079 - val_accuracy: 0.9333
# Epoch 75/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0894 - accuracy: 0.9744 - val_loss: 0.1407 - val_accuracy: 0.9333
# Epoch 76/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0442 - accuracy: 0.9744 - val_loss: 0.1987 - val_accuracy: 0.9333
# Epoch 77/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0403 - accuracy: 0.9915 - val_loss: 0.1851 - val_accuracy: 0.9333
# Epoch 78/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0631 - accuracy: 0.9915 - val_loss: 0.0964 - val_accuracy: 0.9667
# Epoch 79/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0495 - accuracy: 0.9744 - val_loss: 0.1454 - val_accuracy: 0.9333
# Epoch 80/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1570 - accuracy: 0.9402 - val_loss: 0.1717 - val_accuracy: 0.9333
# Epoch 81/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0310 - accuracy: 0.9915 - val_loss: 0.1167 - val_accuracy: 0.9333
# Epoch 82/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0368 - accuracy: 0.9829 - val_loss: 0.1633 - val_accuracy: 0.9333
# Epoch 83/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0366 - accuracy: 0.9744 - val_loss: 0.3433 - val_accuracy: 0.9000
# Epoch 84/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0657 - accuracy: 0.9829 - val_loss: 0.2720 - val_accuracy: 0.9333
# Epoch 85/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0510 - accuracy: 0.9829 - val_loss: 0.3323 - val_accuracy: 0.9000
# Epoch 86/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0586 - accuracy: 0.9915 - val_loss: 0.1686 - val_accuracy: 0.9333
# Epoch 87/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0993 - accuracy: 0.9487 - val_loss: 0.1319 - val_accuracy: 0.9333
# Epoch 88/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0974 - accuracy: 0.9658 - val_loss: 0.0981 - val_accuracy: 0.9667
# Epoch 89/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0443 - accuracy: 0.9829 - val_loss: 0.2167 - val_accuracy: 0.9333
# Epoch 90/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0446 - accuracy: 0.9829 - val_loss: 0.1545 - val_accuracy: 0.9333
# Epoch 91/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0655 - accuracy: 0.9573 - val_loss: 0.1239 - val_accuracy: 0.9667
# Epoch 92/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0321 - accuracy: 0.9829 - val_loss: 0.1773 - val_accuracy: 0.9333
# Epoch 93/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0307 - accuracy: 0.9915 - val_loss: 0.1053 - val_accuracy: 0.9667
# Epoch 94/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0624 - accuracy: 0.9658 - val_loss: 0.6531 - val_accuracy: 0.8000
# Epoch 95/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0620 - accuracy: 0.9744 - val_loss: 0.2228 - val_accuracy: 0.9333
# Epoch 96/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0378 - accuracy: 0.9915 - val_loss: 0.1112 - val_accuracy: 0.9667
# Epoch 97/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0215 - accuracy: 0.9915 - val_loss: 0.1866 - val_accuracy: 0.9333
# Epoch 98/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2562 - accuracy: 0.9402 - val_loss: 0.2544 - val_accuracy: 0.9333
# Epoch 99/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0473 - accuracy: 0.9829 - val_loss: 0.1365 - val_accuracy: 0.9667
# Epoch 100/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0530 - accuracy: 0.9744 - val_loss: 0.3060 - val_accuracy: 0.9333

# %%
#Print actual and predicted value

y_pred = model.predict(X_valid)

actual = np.argmax(y_valid, axis = 1)
predicted = np.argmax(y_pred, axis = 1)

print(f"Actual:    {actual}")
print(f"Predicted: {predicted}")
# Out:
# 1/1 [==============================] - 0s 89ms/step
# Actual:    [2 1 2 0 2 0 1 0 1 0 0 1 2 1 2 1 0 1 2 0 0 2 0 2 1 0 1 2 1 0]
# Predicted: [2 1 2 0 2 0 1 0 2 0 0 1 2 1 2 2 0 1 2 0 0 2 0 2 1 0 1 2 1 0]
